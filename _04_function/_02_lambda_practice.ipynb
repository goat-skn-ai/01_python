# %% [markdown]
# # markdown cell

# %%
# code cell
square = lambda x : x ** 2
print(square(10))
# Out:
# 100

# %%
power = lambda x : x ** 3
print(power(10))
# Out:
# 1000

# %%
a = 10
# Out:
# <function <lambda> at 0x105af2e80>
